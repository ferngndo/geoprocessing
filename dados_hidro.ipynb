# %% [markdown]
# <a href="https://colab.research.google.com/github/ferngndo/geoprocessing/blob/main/dados_hidro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install shapely
# !pip install geopandas

# %%
import geopandas as gpd
from shapely.geometry import Point, LineString, Polygon, MultiPolygon

# %%
hidrografia = gpd.read_file('/content/Hidrografia.shp')

sub_bacias = gpd.read_file('/content/Sub_Bacias_Hidrograficas.shp')

# %%
hidrografia.plot()
# Out:
# <Axes: >

# %%
hidrografia.head()
# Out:
#    objectid  codigo               nome  compriment coberto  trecho  \
# 0         1  002394  VALA DA ANTARTICA   58.164992       S       6
# 1         2  002394  VALA DA ANTARTICA  116.633127       S       4
# 2         3  002394  VALA DA ANTARTICA  113.512820       S       2
# 3         4  000081         RIO BRANCO   65.742407       S       5
# 4         5    None               None  182.209416       S       0
#
#                                             geometry
# 0  LINESTRING (-43.34121 -22.96347, -43.34120 -22...
# 1  LINESTRING (-43.34188 -22.96203, -43.34193 -22...
# 2  LINESTRING (-43.33846 -22.95868, -43.33829 -22...
# 3  LINESTRING (-43.48722 -22.97547, -43.48724 -22...
# 4  LINESTRING (-43.50674 -23.00662, -43.50665 -23...

# %%
hidrografia.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
hidro = hidrografia.to_crs(crs='epsg:31983')

# %%
hidro_buffer = hidro.buffer(100)
hidro_buffer.plot()
# Out:
# <Axes: >

# %%
hidro.length.sum()
# Out:
# 2163792.1761366213

# %%
sub_bacias.plot()
# Out:
# <Axes: >

# %%
bacias = sub_bacias.to_crs(crs='epsg:31983')
bacias.plot()
# Out:
# <Axes: >

# %%
bacias.area.sum()
# Out:
# 1197885589.456582
